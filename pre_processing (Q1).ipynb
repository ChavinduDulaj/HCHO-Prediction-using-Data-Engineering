# %%
import pyspark
import pyspark.sql  as pyspark_sql
import pyspark.sql.types as pyspark_types
import pyspark.sql.functions  as pyspark_functions
from pyspark import SparkContext, SparkConf

# %%
# create the session
conf = SparkConf().set("spark.ui.port", "4050")

# create the context
sc = pyspark.SparkContext(conf=conf)
spark = pyspark_sql.SparkSession.builder.getOrCreate()

# %% [markdown]
# # Dataframe Ops

# %%
# Load the dataset
data1 = spark.read.csv("dataset\col_mat_nuw_output.csv", header=None, inferSchema=True)
data1.show()
# Out:
# +--------------------+--------------+----------+----------+
# |                 _c0|           _c1|       _c2|       _c3|
# +--------------------+--------------+----------+----------+
# |1.969834395781014...|Colombo Proper|2019-01-01|2019-01-02|
# |2.625522171968594...|Colombo Proper|2019-01-02|2019-01-03|
# |9.852118897938794E-5|Colombo Proper|2019-01-03|2019-01-04|
# |2.099320518114242E-4|Colombo Proper|2019-01-04|2019-01-05|
# |1.785337298892930...|Colombo Proper|2019-01-05|2019-01-06|
# |1.082296700235670...|Colombo Proper|2019-01-06|2019-01-07|
# |3.926829280477309...|Colombo Proper|2019-01-07|2019-01-08|
# |9.153156350685351E-5|Colombo Proper|2019-01-08|2019-01-09|
# |1.205978992853015...|Colombo Proper|2019-01-09|2019-01-10|
# |1.297723562983258...|Colombo Proper|2019-01-10|2019-01-11|
# |2.239188166801278...|Colombo Proper|2019-01-11|2019-01-12|
# |1.569418094178759...|Colombo Proper|2019-01-12|2019-01-13|
# |                NULL|Colombo Proper|2019-01-13|2019-01-14|
# |1.336291906862603...|Colombo Proper|2019-01-14|2019-01-15|
# |6.374417842690063E-5|Colombo Proper|2019-01-15|2019-01-16|
# |1.181062250815020...|Colombo Proper|2019-01-16|2019-01-17|
# |2.472555222423037...|Colombo Proper|2019-01-17|2019-01-18|
# |3.667525352047757E-5|Colombo Proper|2019-01-18|2019-01-19|
# |4.057500868150313E-4|Colombo Proper|2019-01-19|2019-01-20|
# |1.687856216479722...|Colombo Proper|2019-01-20|2019-01-21|
# +--------------------+--------------+----------+----------+
# only showing top 20 rows

# %%
data2 = spark.read.csv("dataset\kan_output.csv", header=None, inferSchema=True)
data2.show()
# Out:
# +--------------------+------------+----------+----------+
# |                 _c0|         _c1|       _c2|       _c3|
# +--------------------+------------+----------+----------+
# |1.760713459877335...|Kandy Proper|2019-01-01|2019-01-02|
# |9.220391253917748E-5|Kandy Proper|2019-01-02|2019-01-03|
# |                NULL|Kandy Proper|2019-01-03|2019-01-04|
# |1.908681983853839...|Kandy Proper|2019-01-04|2019-01-05|
# |1.219517840206744...|Kandy Proper|2019-01-05|2019-01-06|
# |-6.51408612938880...|Kandy Proper|2019-01-06|2019-01-07|
# |  1.6323820639265E-4|Kandy Proper|2019-01-07|2019-01-08|
# |-6.73520553391426...|Kandy Proper|2019-01-08|2019-01-09|
# |1.279693658243135...|Kandy Proper|2019-01-09|2019-01-10|
# |4.546048424126012E-5|Kandy Proper|2019-01-10|2019-01-11|
# |3.600074175192105E-5|Kandy Proper|2019-01-11|2019-01-12|
# |1.286629698010177E-4|Kandy Proper|2019-01-12|2019-01-13|
# |                NULL|Kandy Proper|2019-01-13|2019-01-14|
# |                NULL|Kandy Proper|2019-01-14|2019-01-15|
# | 9.63639634671553E-5|Kandy Proper|2019-01-15|2019-01-16|
# |                NULL|Kandy Proper|2019-01-16|2019-01-17|
# |1.200971278484736...|Kandy Proper|2019-01-17|2019-01-18|
# |-1.19724656713695...|Kandy Proper|2019-01-18|2019-01-19|
# |2.825263761529470...|Kandy Proper|2019-01-19|2019-01-20|
# |7.150631692646835E-5|Kandy Proper|2019-01-20|2019-01-21|
# +--------------------+------------+----------+----------+
# only showing top 20 rows

# %%
data3 = spark.read.csv("dataset\mon_kur_jaf_output.csv", header=None, inferSchema=True)
data3.show()
# Out:
# +--------------------+------------------+----------+----------+
# |                 _c0|               _c1|       _c2|       _c3|
# +--------------------+------------------+----------+----------+
# |                NULL|Bibile, Monaragala|2019-01-01|2019-01-02|
# |1.919914652467399E-5|Bibile, Monaragala|2019-01-02|2019-01-03|
# |2.811447935930283...|Bibile, Monaragala|2019-01-03|2019-01-04|
# |3.747998184385943E-5|Bibile, Monaragala|2019-01-04|2019-01-05|
# |-1.79826087934531...|Bibile, Monaragala|2019-01-05|2019-01-06|
# |1.457836896179902...|Bibile, Monaragala|2019-01-06|2019-01-07|
# |2.828590802546534...|Bibile, Monaragala|2019-01-07|2019-01-08|
# |                NULL|Bibile, Monaragala|2019-01-08|2019-01-09|
# |1.420850167050957...|Bibile, Monaragala|2019-01-09|2019-01-10|
# |                NULL|Bibile, Monaragala|2019-01-10|2019-01-11|
# |2.014587947072581E-5|Bibile, Monaragala|2019-01-11|2019-01-12|
# |1.582787663210183...|Bibile, Monaragala|2019-01-12|2019-01-13|
# |                NULL|Bibile, Monaragala|2019-01-13|2019-01-14|
# |                NULL|Bibile, Monaragala|2019-01-14|2019-01-15|
# |9.952823849642218E-5|Bibile, Monaragala|2019-01-15|2019-01-16|
# |7.484570960514249E-5|Bibile, Monaragala|2019-01-16|2019-01-17|
# |7.736112226328797E-5|Bibile, Monaragala|2019-01-17|2019-01-18|
# |                NULL|Bibile, Monaragala|2019-01-18|2019-01-19|
# |3.988141010407665...|Bibile, Monaragala|2019-01-19|2019-01-20|
# |1.891620203853342...|Bibile, Monaragala|2019-01-20|2019-01-21|
# +--------------------+------------------+----------+----------+
# only showing top 20 rows

# %%
column_names = ['HCHO', 'Location', 'Current date', 'Next date']

for i, new_name in enumerate(column_names):
    data1 = data1.withColumnRenamed(data1.columns[i], new_name)

data1.show()
# Out:
# +--------------------+--------------+------------+----------+
# |                HCHO|      Location|Current date| Next date|
# +--------------------+--------------+------------+----------+
# |1.969834395781014...|Colombo Proper|  2019-01-01|2019-01-02|
# |2.625522171968594...|Colombo Proper|  2019-01-02|2019-01-03|
# |9.852118897938794E-5|Colombo Proper|  2019-01-03|2019-01-04|
# |2.099320518114242E-4|Colombo Proper|  2019-01-04|2019-01-05|
# |1.785337298892930...|Colombo Proper|  2019-01-05|2019-01-06|
# |1.082296700235670...|Colombo Proper|  2019-01-06|2019-01-07|
# |3.926829280477309...|Colombo Proper|  2019-01-07|2019-01-08|
# |9.153156350685351E-5|Colombo Proper|  2019-01-08|2019-01-09|
# |1.205978992853015...|Colombo Proper|  2019-01-09|2019-01-10|
# |1.297723562983258...|Colombo Proper|  2019-01-10|2019-01-11|
# |2.239188166801278...|Colombo Proper|  2019-01-11|2019-01-12|
# |1.569418094178759...|Colombo Proper|  2019-01-12|2019-01-13|
# |                NULL|Colombo Proper|  2019-01-13|2019-01-14|
# |1.336291906862603...|Colombo Proper|  2019-01-14|2019-01-15|
# |6.374417842690063E-5|Colombo Proper|  2019-01-15|2019-01-16|
# |1.181062250815020...|Colombo Proper|  2019-01-16|2019-01-17|
# |2.472555222423037...|Colombo Proper|  2019-01-17|2019-01-18|
# |3.667525352047757E-5|Colombo Proper|  2019-01-18|2019-01-19|
# |4.057500868150313E-4|Colombo Proper|  2019-01-19|2019-01-20|
# |1.687856216479722...|Colombo Proper|  2019-01-20|2019-01-21|
# +--------------------+--------------+------------+----------+
# only showing top 20 rows

# %%
column_names = ['HCHO', 'Location', 'Current date', 'Next date']

for i, new_name in enumerate(column_names):
    data2 = data2.withColumnRenamed(data2.columns[i], new_name)

data2.show()
# Out:
# +--------------------+------------+------------+----------+
# |                HCHO|    Location|Current date| Next date|
# +--------------------+------------+------------+----------+
# |1.760713459877335...|Kandy Proper|  2019-01-01|2019-01-02|
# |9.220391253917748E-5|Kandy Proper|  2019-01-02|2019-01-03|
# |                NULL|Kandy Proper|  2019-01-03|2019-01-04|
# |1.908681983853839...|Kandy Proper|  2019-01-04|2019-01-05|
# |1.219517840206744...|Kandy Proper|  2019-01-05|2019-01-06|
# |-6.51408612938880...|Kandy Proper|  2019-01-06|2019-01-07|
# |  1.6323820639265E-4|Kandy Proper|  2019-01-07|2019-01-08|
# |-6.73520553391426...|Kandy Proper|  2019-01-08|2019-01-09|
# |1.279693658243135...|Kandy Proper|  2019-01-09|2019-01-10|
# |4.546048424126012E-5|Kandy Proper|  2019-01-10|2019-01-11|
# |3.600074175192105E-5|Kandy Proper|  2019-01-11|2019-01-12|
# |1.286629698010177E-4|Kandy Proper|  2019-01-12|2019-01-13|
# |                NULL|Kandy Proper|  2019-01-13|2019-01-14|
# |                NULL|Kandy Proper|  2019-01-14|2019-01-15|
# | 9.63639634671553E-5|Kandy Proper|  2019-01-15|2019-01-16|
# |                NULL|Kandy Proper|  2019-01-16|2019-01-17|
# |1.200971278484736...|Kandy Proper|  2019-01-17|2019-01-18|
# |-1.19724656713695...|Kandy Proper|  2019-01-18|2019-01-19|
# |2.825263761529470...|Kandy Proper|  2019-01-19|2019-01-20|
# |7.150631692646835E-5|Kandy Proper|  2019-01-20|2019-01-21|
# +--------------------+------------+------------+----------+
# only showing top 20 rows

# %%
column_names = ['HCHO', 'Location', 'Current date', 'Next date']

for i, new_name in enumerate(column_names):
    data3 = data3.withColumnRenamed(data3.columns[i], new_name)

data3.show()
# Out:
# +--------------------+------------------+------------+----------+
# |                HCHO|          Location|Current date| Next date|
# +--------------------+------------------+------------+----------+
# |                NULL|Bibile, Monaragala|  2019-01-01|2019-01-02|
# |1.919914652467399E-5|Bibile, Monaragala|  2019-01-02|2019-01-03|
# |2.811447935930283...|Bibile, Monaragala|  2019-01-03|2019-01-04|
# |3.747998184385943E-5|Bibile, Monaragala|  2019-01-04|2019-01-05|
# |-1.79826087934531...|Bibile, Monaragala|  2019-01-05|2019-01-06|
# |1.457836896179902...|Bibile, Monaragala|  2019-01-06|2019-01-07|
# |2.828590802546534...|Bibile, Monaragala|  2019-01-07|2019-01-08|
# |                NULL|Bibile, Monaragala|  2019-01-08|2019-01-09|
# |1.420850167050957...|Bibile, Monaragala|  2019-01-09|2019-01-10|
# |                NULL|Bibile, Monaragala|  2019-01-10|2019-01-11|
# |2.014587947072581E-5|Bibile, Monaragala|  2019-01-11|2019-01-12|
# |1.582787663210183...|Bibile, Monaragala|  2019-01-12|2019-01-13|
# |                NULL|Bibile, Monaragala|  2019-01-13|2019-01-14|
# |                NULL|Bibile, Monaragala|  2019-01-14|2019-01-15|
# |9.952823849642218E-5|Bibile, Monaragala|  2019-01-15|2019-01-16|
# |7.484570960514249E-5|Bibile, Monaragala|  2019-01-16|2019-01-17|
# |7.736112226328797E-5|Bibile, Monaragala|  2019-01-17|2019-01-18|
# |                NULL|Bibile, Monaragala|  2019-01-18|2019-01-19|
# |3.988141010407665...|Bibile, Monaragala|  2019-01-19|2019-01-20|
# |1.891620203853342...|Bibile, Monaragala|  2019-01-20|2019-01-21|
# +--------------------+------------------+------------+----------+
# only showing top 20 rows

# %%
# Concatenate DataFrames vertically
concatenated_df = data1.union(data2).union(data3)

# Show the concatenated DataFrame
concatenated_df.show(300)
# Out:
# +--------------------+--------------+------------+----------+
# |                HCHO|      Location|Current date| Next date|
# +--------------------+--------------+------------+----------+
# |1.969834395781014...|Colombo Proper|  2019-01-01|2019-01-02|
# |2.625522171968594...|Colombo Proper|  2019-01-02|2019-01-03|
# |9.852118897938794E-5|Colombo Proper|  2019-01-03|2019-01-04|
# |2.099320518114242E-4|Colombo Proper|  2019-01-04|2019-01-05|
# |1.785337298892930...|Colombo Proper|  2019-01-05|2019-01-06|
# |1.082296700235670...|Colombo Proper|  2019-01-06|2019-01-07|
# |3.926829280477309...|Colombo Proper|  2019-01-07|2019-01-08|
# |9.153156350685351E-5|Colombo Proper|  2019-01-08|2019-01-09|
# |1.205978992853015...|Colombo Proper|  2019-01-09|2019-01-10|
# |1.297723562983258...|Colombo Proper|  2019-01-10|2019-01-11|
# |2.239188166801278...|Colombo Proper|  2019-01-11|2019-01-12|
# |1.569418094178759...|Colombo Proper|  2019-01-12|2019-01-13|
# |                NULL|Colombo Proper|  2019-01-13|2019-01-14|
# |1.336291906862603...|Colombo Proper|  2019-01-14|2019-01-15|
# |6.374417842690063E-5|Colombo Proper|  2019-01-15|2019-01-16|
# |1.181062250815020...|Colombo Proper|  2019-01-16|2019-01-17|
# |2.472555222423037...|Colombo Proper|  2019-01-17|2019-01-18|
# |3.667525352047757E-5|Colombo Proper|  2019-01-18|2019-01-19|
# |4.057500868150313E-4|Colombo Proper|  2019-01-19|2019-01-20|
# |1.687856216479722...|Colombo Proper|  2019-01-20|2019-01-21|
# |3.881549328739672...|Colombo Proper|  2019-01-21|2019-01-22|
# |3.282922940445869E-4|Colombo Proper|  2019-01-22|2019-01-23|
# |2.147798144691999...|Colombo Proper|  2019-01-23|2019-01-24|
# |2.347245196410463E-4|Colombo Proper|  2019-01-24|2019-01-25|
# |2.820915300341781E-4|Colombo Proper|  2019-01-25|2019-01-26|
# |2.507263493088431...|Colombo Proper|  2019-01-26|2019-01-27|
# |1.973288435314463...|Colombo Proper|  2019-01-27|2019-01-28|
# |2.555121674807678E-4|Colombo Proper|  2019-01-28|2019-01-29|
# |                NULL|Colombo Proper|  2019-01-29|2019-01-30|
# |1.713635736010489...|Colombo Proper|  2019-01-30|2019-01-31|
# |1.523802119023603...|Colombo Proper|  2019-01-31|2019-02-01|
# |3.537610010169976E-4|Colombo Proper|  2019-02-01|2019-02-02|
# |2.755728995643352...|Colombo Proper|  2019-02-02|2019-02-03|
# | 2.31884649807831E-4|Colombo Proper|  2019-02-03|2019-02-04|
# |                NULL|Colombo Proper|  2019-02-04|2019-02-05|
# |3.618487680796534E-4|Colombo Proper|  2019-02-05|2019-02-06|
# |3.430663631539430...|Colombo Proper|  2019-02-06|2019-02-07|
# |2.123314538243048E-4|Colombo Proper|  2019-02-07|2019-02-08|
# |1.679798012516793E-4|Colombo Proper|  2019-02-08|2019-02-09|
# | 3.81605036888715E-4|Colombo Proper|  2019-02-09|2019-02-10|
# |2.650819171274837...|Colombo Proper|  2019-02-10|2019-02-11|
# |1.981789630254356E-4|Colombo Proper|  2019-02-11|2019-02-12|
# |5.858717850060201...|Colombo Proper|  2019-02-12|2019-02-13|
# |2.542805951476315...|Colombo Proper|  2019-02-13|2019-02-14|
# |                NULL|Colombo Proper|  2019-02-14|2019-02-15|
# |2.239912172577585E-4|Colombo Proper|  2019-02-15|2019-02-16|
# |2.091493159849644...|Colombo Proper|  2019-02-16|2019-02-17|
# |1.262731392288914E-4|Colombo Proper|  2019-02-17|2019-02-18|
# |2.255146318446467...|Colombo Proper|  2019-02-18|2019-02-19|
# |3.180786698506332...|Colombo Proper|  2019-02-19|2019-02-20|
# |2.720768387394868E-4|Colombo Proper|  2019-02-20|2019-02-21|
# |2.230429464187653E-4|Colombo Proper|  2019-02-21|2019-02-22|
# |3.148949841717713E-4|Colombo Proper|  2019-02-22|2019-02-23|
# |3.274182238715349E-4|Colombo Proper|  2019-02-23|2019-02-24|
# |2.362989851716369...|Colombo Proper|  2019-02-24|2019-02-25|
# |2.424675429303956...|Colombo Proper|  2019-02-25|2019-02-26|
# |1.564597489260421...|Colombo Proper|  2019-02-26|2019-02-27|
# |1.542016842877319...|Colombo Proper|  2019-02-27|2019-02-28|
# |2.270067709833573...|Colombo Proper|  2019-02-28|2019-03-01|
# |                NULL|Colombo Proper|  2019-03-01|2019-03-02|
# |                NULL|Colombo Proper|  2019-03-02|2019-03-03|
# |2.934140276437700...|Colombo Proper|  2019-03-03|2019-03-04|
# |2.222321497741398...|Colombo Proper|  2019-03-04|2019-03-05|
# |4.259884693025736...|Colombo Proper|  2019-03-05|2019-03-06|
# |1.358519584920060...|Colombo Proper|  2019-03-06|2019-03-07|
# |2.023807303628845...|Colombo Proper|  2019-03-07|2019-03-08|
# |1.644238164367392...|Colombo Proper|  2019-03-08|2019-03-09|
# |                NULL|Colombo Proper|  2019-03-09|2019-03-10|
# |2.969609827467505E-4|Colombo Proper|  2019-03-10|2019-03-11|
# |2.401309050569976...|Colombo Proper|  2019-03-11|2019-03-12|
# |2.577451751777237E-4|Colombo Proper|  2019-03-12|2019-03-13|
# |2.548286008604607E-4|Colombo Proper|  2019-03-13|2019-03-14|
# |3.018449398759976E-4|Colombo Proper|  2019-03-14|2019-03-15|
# |1.790542755015718...|Colombo Proper|  2019-03-15|2019-03-16|
# |3.507194301071738E-4|Colombo Proper|  2019-03-16|2019-03-17|
# |2.494769497451432E-4|Colombo Proper|  2019-03-17|2019-03-18|
# |                NULL|Colombo Proper|  2019-03-18|2019-03-19|
# |2.074590335083668...|Colombo Proper|  2019-03-19|2019-03-20|
# |2.559950022304003E-4|Colombo Proper|  2019-03-20|2019-03-21|
# |                NULL|Colombo Proper|  2019-03-21|2019-03-22|
# |2.689655073385781E-4|Colombo Proper|  2019-03-22|2019-03-23|
# |1.440055508380318...|Colombo Proper|  2019-03-23|2019-03-24|
# |2.204458373225478...|Colombo Proper|  2019-03-24|2019-03-25|
# |3.577663287879659E-4|Colombo Proper|  2019-03-25|2019-03-26|
# |2.631266925609883E-4|Colombo Proper|  2019-03-26|2019-03-27|
# |3.646052956171703E-4|Colombo Proper|  2019-03-27|2019-03-28|
# |3.906452278091737...|Colombo Proper|  2019-03-28|2019-03-29|
# |2.540006405394258E-4|Colombo Proper|  2019-03-29|2019-03-30|
# |2.202186895424861...|Colombo Proper|  2019-03-30|2019-03-31|
# |1.155774606754469...|Colombo Proper|  2019-03-31|2019-04-01|
# |1.234932174866924...|Colombo Proper|  2019-04-01|2019-04-02|
# |2.688230247372582E-4|Colombo Proper|  2019-04-02|2019-04-03|
# |                NULL|Colombo Proper|  2019-04-03|2019-04-04|
# |2.401417063094139...|Colombo Proper|  2019-04-04|2019-04-05|
# |1.694011577926113...|Colombo Proper|  2019-04-05|2019-04-06|
# |1.030405027441702...|Colombo Proper|  2019-04-06|2019-04-07|
# |1.799434891600914E-4|Colombo Proper|  2019-04-07|2019-04-08|
# |1.938136388473303E-4|Colombo Proper|  2019-04-08|2019-04-09|
# |2.005766244694444E-4|Colombo Proper|  2019-04-09|2019-04-10|
# |2.045066130365929...|Colombo Proper|  2019-04-10|2019-04-11|
# |2.787301089676465E-4|Colombo Proper|  2019-04-11|2019-04-12|
# |2.500758492520154E-4|Colombo Proper|  2019-04-12|2019-04-13|
# | 3.34870158729018E-4|Colombo Proper|  2019-04-13|2019-04-14|
# |                NULL|Colombo Proper|  2019-04-14|2019-04-15|
# |                NULL|Colombo Proper|  2019-04-15|2019-04-16|
# |                NULL|Colombo Proper|  2019-04-16|2019-04-17|
# |                NULL|Colombo Proper|  2019-04-17|2019-04-18|
# |1.927819063126676...|Colombo Proper|  2019-04-18|2019-04-19|
# |                NULL|Colombo Proper|  2019-04-19|2019-04-20|
# |1.442130580330848E-4|Colombo Proper|  2019-04-20|2019-04-21|
# |1.454167284999811...|Colombo Proper|  2019-04-21|2019-04-22|
# |1.711205695593238...|Colombo Proper|  2019-04-22|2019-04-23|
# |2.932244406430172...|Colombo Proper|  2019-04-23|2019-04-24|
# |1.399382956399640...|Colombo Proper|  2019-04-24|2019-04-25|
# |9.581443666026757E-5|Colombo Proper|  2019-04-25|2019-04-26|
# |                NULL|Colombo Proper|  2019-04-26|2019-04-27|
# |                NULL|Colombo Proper|  2019-04-27|2019-04-28|
# |                NULL|Colombo Proper|  2019-04-28|2019-04-29|
# |                NULL|Colombo Proper|  2019-04-29|2019-04-30|
# |                NULL|Colombo Proper|  2019-04-30|2019-05-01|
# |9.747576626042275E-5|Colombo Proper|  2019-05-01|2019-05-02|
# |                NULL|Colombo Proper|  2019-05-02|2019-05-03|
# |                NULL|Colombo Proper|  2019-05-03|2019-05-04|
# |1.008724552225438...|Colombo Proper|  2019-05-04|2019-05-05|
# |                NULL|Colombo Proper|  2019-05-05|2019-05-06|
# |3.904429319723554E-5|Colombo Proper|  2019-05-06|2019-05-07|
# |1.174876039439607...|Colombo Proper|  2019-05-07|2019-05-08|
# |1.013037943240832E-4|Colombo Proper|  2019-05-08|2019-05-09|
# |9.939428098153852E-5|Colombo Proper|  2019-05-09|2019-05-10|
# |1.253641582710813...|Colombo Proper|  2019-05-10|2019-05-11|
# |1.274753051841466E-4|Colombo Proper|  2019-05-11|2019-05-12|
# |8.802823548435995E-5|Colombo Proper|  2019-05-12|2019-05-13|
# |2.498220490116862...|Colombo Proper|  2019-05-13|2019-05-14|
# |1.810438022415624...|Colombo Proper|  2019-05-14|2019-05-15|
# |1.394291724461167...|Colombo Proper|  2019-05-15|2019-05-16|
# |1.171367229027294...|Colombo Proper|  2019-05-16|2019-05-17|
# |1.095084478863608E-4|Colombo Proper|  2019-05-17|2019-05-18|
# |9.525618991159471E-5|Colombo Proper|  2019-05-18|2019-05-19|
# |8.700221402162398E-5|Colombo Proper|  2019-05-19|2019-05-20|
# |3.986268368399866E-4|Colombo Proper|  2019-05-20|2019-05-21|
# |                NULL|Colombo Proper|  2019-05-21|2019-05-22|
# |                NULL|Colombo Proper|  2019-05-22|2019-05-23|
# |2.171247684173245...|Colombo Proper|  2019-05-23|2019-05-24|
# |                NULL|Colombo Proper|  2019-05-24|2019-05-25|
# |1.897835067573190...|Colombo Proper|  2019-05-25|2019-05-26|
# |1.107802238700500...|Colombo Proper|  2019-05-26|2019-05-27|
# |1.368899250486834...|Colombo Proper|  2019-05-27|2019-05-28|
# |1.659967379550117...|Colombo Proper|  2019-05-28|2019-05-29|
# |-2.05680821584637...|Colombo Proper|  2019-05-29|2019-05-30|
# |2.179323946145343...|Colombo Proper|  2019-05-30|2019-05-31|
# |9.379307690791867E-5|Colombo Proper|  2019-05-31|2019-06-01|
# |7.067572073902713E-5|Colombo Proper|  2019-06-01|2019-06-02|
# |1.658041001064703E-4|Colombo Proper|  2019-06-02|2019-06-03|
# |1.609821398171031E-4|Colombo Proper|  2019-06-03|2019-06-04|
# | 8.42250633206326E-5|Colombo Proper|  2019-06-04|2019-06-05|
# |                NULL|Colombo Proper|  2019-06-05|2019-06-06|
# |                NULL|Colombo Proper|  2019-06-06|2019-06-07|
# |                NULL|Colombo Proper|  2019-06-07|2019-06-08|
# |1.221799295052856...|Colombo Proper|  2019-06-08|2019-06-09|
# | 1.84304139111191E-4|Colombo Proper|  2019-06-09|2019-06-10|
# |                NULL|Colombo Proper|  2019-06-10|2019-06-11|
# | 8.17687223806277E-5|Colombo Proper|  2019-06-11|2019-06-12|
# |1.880614290712401...|Colombo Proper|  2019-06-12|2019-06-13|
# |2.328588614328030...|Colombo Proper|  2019-06-13|2019-06-14|
# |8.209911205126233E-5|Colombo Proper|  2019-06-14|2019-06-15|
# |1.636562089987276...|Colombo Proper|  2019-06-15|2019-06-16|
# |                NULL|Colombo Proper|  2019-06-16|2019-06-17|
# |1.534455988928557...|Colombo Proper|  2019-06-17|2019-06-18|
# |1.583308135730508...|Colombo Proper|  2019-06-18|2019-06-19|
# |1.450758394609547...|Colombo Proper|  2019-06-19|2019-06-20|
# |                NULL|Colombo Proper|  2019-06-20|2019-06-21|
# |                NULL|Colombo Proper|  2019-06-21|2019-06-22|
# |1.403497627398723...|Colombo Proper|  2019-06-22|2019-06-23|
# |1.979226944313850...|Colombo Proper|  2019-06-23|2019-06-24|
# |2.885739086195826...|Colombo Proper|  2019-06-24|2019-06-25|
# |1.698958410235636...|Colombo Proper|  2019-06-25|2019-06-26|
# |-1.71888277691323...|Colombo Proper|  2019-06-26|2019-06-27|
# |1.242156863718755...|Colombo Proper|  2019-06-27|2019-06-28|
# |8.171133330754701E-5|Colombo Proper|  2019-06-28|2019-06-29|
# |7.340520263976472E-5|Colombo Proper|  2019-06-29|2019-06-30|
# |2.096451370757018...|Colombo Proper|  2019-06-30|2019-07-01|
# |8.969739342465703E-5|Colombo Proper|  2019-07-01|2019-07-02|
# |8.080856806689084E-5|Colombo Proper|  2019-07-02|2019-07-03|
# |2.889810298407616E-5|Colombo Proper|  2019-07-03|2019-07-04|
# |8.317285235618187E-5|Colombo Proper|  2019-07-04|2019-07-05|
# |9.391269191043181E-5|Colombo Proper|  2019-07-05|2019-07-06|
# |9.547040684925105E-6|Colombo Proper|  2019-07-06|2019-07-07|
# |9.452725531817138E-7|Colombo Proper|  2019-07-07|2019-07-08|
# |1.606779140439455...|Colombo Proper|  2019-07-08|2019-07-09|
# |                NULL|Colombo Proper|  2019-07-09|2019-07-10|
# |5.047959159020286E-5|Colombo Proper|  2019-07-10|2019-07-11|
# |6.685329661024943E-5|Colombo Proper|  2019-07-11|2019-07-12|
# |1.352754338604427...|Colombo Proper|  2019-07-12|2019-07-13|
# |                NULL|Colombo Proper|  2019-07-13|2019-07-14|
# |                NULL|Colombo Proper|  2019-07-14|2019-07-15|
# |                NULL|Colombo Proper|  2019-07-15|2019-07-16|
# | 9.32507996651824E-5|Colombo Proper|  2019-07-16|2019-07-17|
# |                NULL|Colombo Proper|  2019-07-17|2019-07-18|
# |                NULL|Colombo Proper|  2019-07-18|2019-07-19|
# |                NULL|Colombo Proper|  2019-07-19|2019-07-20|
# | 9.77121531808704E-5|Colombo Proper|  2019-07-20|2019-07-21|
# |1.328017366567373E-4|Colombo Proper|  2019-07-21|2019-07-22|
# |                NULL|Colombo Proper|  2019-07-22|2019-07-23|
# |-1.03601422787331...|Colombo Proper|  2019-07-23|2019-07-24|
# |5.203873014574210...|Colombo Proper|  2019-07-24|2019-07-25|
# |1.644546205319502E-4|Colombo Proper|  2019-07-25|2019-07-26|
# |1.707607001308167...|Colombo Proper|  2019-07-26|2019-07-27|
# |1.185044673927642...|Colombo Proper|  2019-07-27|2019-07-28|
# |1.041769215942744E-4|Colombo Proper|  2019-07-28|2019-07-29|
# |1.754362061189736...|Colombo Proper|  2019-07-29|2019-07-30|
# |4.695525304950444...|Colombo Proper|  2019-07-30|2019-07-31|
# |9.259486707748455E-5|Colombo Proper|  2019-07-31|2019-08-01|
# |4.458029389653336E-5|Colombo Proper|  2019-08-01|2019-08-02|
# |                NULL|Colombo Proper|  2019-08-02|2019-08-03|
# | 6.93505158442184E-5|Colombo Proper|  2019-08-03|2019-08-04|
# |-2.35063016577371...|Colombo Proper|  2019-08-04|2019-08-05|
# |4.396326486663662...|Colombo Proper|  2019-08-05|2019-08-06|
# |5.951792946298224E-5|Colombo Proper|  2019-08-06|2019-08-07|
# |2.358972517484437E-4|Colombo Proper|  2019-08-07|2019-08-08|
# |                NULL|Colombo Proper|  2019-08-08|2019-08-09|
# |-3.75313275350291...|Colombo Proper|  2019-08-09|2019-08-10|
# |                NULL|Colombo Proper|  2019-08-10|2019-08-11|
# |1.621829232794947...|Colombo Proper|  2019-08-11|2019-08-12|
# |                NULL|Colombo Proper|  2019-08-12|2019-08-13|
# |                NULL|Colombo Proper|  2019-08-13|2019-08-14|
# |5.860973694382833E-5|Colombo Proper|  2019-08-14|2019-08-15|
# |1.350586133809714...|Colombo Proper|  2019-08-15|2019-08-16|
# |                NULL|Colombo Proper|  2019-08-16|2019-08-17|
# |1.685731549514457...|Colombo Proper|  2019-08-17|2019-08-18|
# |3.706723761402327E-5|Colombo Proper|  2019-08-18|2019-08-19|
# |8.584961620742005E-5|Colombo Proper|  2019-08-19|2019-08-20|
# |8.793838791530453E-5|Colombo Proper|  2019-08-20|2019-08-21|
# |8.479952216441172E-5|Colombo Proper|  2019-08-21|2019-08-22|
# |                NULL|Colombo Proper|  2019-08-22|2019-08-23|
# |                NULL|Colombo Proper|  2019-08-23|2019-08-24|
# |1.512307072603007...|Colombo Proper|  2019-08-24|2019-08-25|
# |2.832087779864206...|Colombo Proper|  2019-08-25|2019-08-26|
# |                NULL|Colombo Proper|  2019-08-26|2019-08-27|
# |                NULL|Colombo Proper|  2019-08-27|2019-08-28|
# |1.893734588520601...|Colombo Proper|  2019-08-28|2019-08-29|
# |3.315822687000035...|Colombo Proper|  2019-08-29|2019-08-30|
# |-2.29102592175331...|Colombo Proper|  2019-08-30|2019-08-31|
# |4.148157993699298E-5|Colombo Proper|  2019-08-31|2019-09-01|
# |1.181930895847604...|Colombo Proper|  2019-09-01|2019-09-02|
# |1.254869544792329...|Colombo Proper|  2019-09-02|2019-09-03|
# |2.227865399441433...|Colombo Proper|  2019-09-03|2019-09-04|
# |6.601078846206005E-5|Colombo Proper|  2019-09-04|2019-09-05|
# |6.189868745003109E-5|Colombo Proper|  2019-09-05|2019-09-06|
# | 6.96768756388925E-6|Colombo Proper|  2019-09-06|2019-09-07|
# | 1.42528222764163E-4|Colombo Proper|  2019-09-07|2019-09-08|
# |1.051981676809497...|Colombo Proper|  2019-09-08|2019-09-09|
# |7.796198665621607E-5|Colombo Proper|  2019-09-09|2019-09-10|
# |1.706459092882999...|Colombo Proper|  2019-09-10|2019-09-11|
# |                NULL|Colombo Proper|  2019-09-11|2019-09-12|
# |                NULL|Colombo Proper|  2019-09-12|2019-09-13|
# |                NULL|Colombo Proper|  2019-09-13|2019-09-14|
# | -2.7079145498339E-5|Colombo Proper|  2019-09-14|2019-09-15|
# |-1.08499807538464...|Colombo Proper|  2019-09-15|2019-09-16|
# |                NULL|Colombo Proper|  2019-09-16|2019-09-17|
# |7.293194215549228E-5|Colombo Proper|  2019-09-17|2019-09-18|
# |1.224324055217149...|Colombo Proper|  2019-09-18|2019-09-19|
# |                NULL|Colombo Proper|  2019-09-19|2019-09-20|
# |4.430466275593557...|Colombo Proper|  2019-09-20|2019-09-21|
# |6.719672168285214E-5|Colombo Proper|  2019-09-21|2019-09-22|
# |                NULL|Colombo Proper|  2019-09-22|2019-09-23|
# |                NULL|Colombo Proper|  2019-09-23|2019-09-24|
# |                NULL|Colombo Proper|  2019-09-24|2019-09-25|
# |                NULL|Colombo Proper|  2019-09-25|2019-09-26|
# |3.582177450880408...|Colombo Proper|  2019-09-26|2019-09-27|
# |1.222516306589816...|Colombo Proper|  2019-09-27|2019-09-28|
# |2.095719037861284E-4|Colombo Proper|  2019-09-28|2019-09-29|
# |1.578932214216887...|Colombo Proper|  2019-09-29|2019-09-30|
# |1.080054580652660...|Colombo Proper|  2019-09-30|2019-10-01|
# |1.737579768947595E-4|Colombo Proper|  2019-10-01|2019-10-02|
# |8.218956230442276E-5|Colombo Proper|  2019-10-02|2019-10-03|
# |3.043901944550457E-4|Colombo Proper|  2019-10-03|2019-10-04|
# |4.704659868522847E-5|Colombo Proper|  2019-10-04|2019-10-05|
# | 1.75775737113565E-4|Colombo Proper|  2019-10-05|2019-10-06|
# |                NULL|Colombo Proper|  2019-10-06|2019-10-07|
# |3.090292903243917E-5|Colombo Proper|  2019-10-07|2019-10-08|
# |1.416648182430768...|Colombo Proper|  2019-10-08|2019-10-09|
# |1.721947790897597...|Colombo Proper|  2019-10-09|2019-10-10|
# |1.929062722760271E-4|Colombo Proper|  2019-10-10|2019-10-11|
# |                NULL|Colombo Proper|  2019-10-11|2019-10-12|
# |                NULL|Colombo Proper|  2019-10-12|2019-10-13|
# |1.498612726906845...|Colombo Proper|  2019-10-13|2019-10-14|
# |8.925810029372805E-5|Colombo Proper|  2019-10-14|2019-10-15|
# |1.820320412200815...|Colombo Proper|  2019-10-15|2019-10-16|
# |1.768249399084822...|Colombo Proper|  2019-10-16|2019-10-17|
# |4.544709803342311E-5|Colombo Proper|  2019-10-17|2019-10-18|
# |1.029842285738716...|Colombo Proper|  2019-10-18|2019-10-19|
# |1.662220724960804...|Colombo Proper|  2019-10-19|2019-10-20|
# |6.604724330827594E-5|Colombo Proper|  2019-10-20|2019-10-21|
# |                NULL|Colombo Proper|  2019-10-21|2019-10-22|
# |                NULL|Colombo Proper|  2019-10-22|2019-10-23|
# |1.471854356328425...|Colombo Proper|  2019-10-23|2019-10-24|
# |                NULL|Colombo Proper|  2019-10-24|2019-10-25|
# |                NULL|Colombo Proper|  2019-10-25|2019-10-26|
# |                NULL|Colombo Proper|  2019-10-26|2019-10-27|
# |                NULL|Colombo Proper|  2019-10-27|2019-10-28|
# +--------------------+--------------+------------+----------+
# only showing top 300 rows

# %%
import pandas as pd

# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = concatenated_df.toPandas()

# Specify the output path where you want to save the CSV file
output_path_pandas = "dataset/concatenated_pandas.csv"

# Save the Pandas DataFrame to a CSV file
pandas_df.to_csv(output_path_pandas, index=False)

# Provide feedback to the user
print(f"Pandas DataFrame saved to {output_path_pandas}")
# Out:
# Pandas DataFrame saved to dataset/concatenated_pandas.csv

# %%
concatenated_df.describe()
# Out:
# DataFrame[summary: string, HCHO: string, Location: string]

# %%
from pyspark.sql.functions import col, sum

# Checking the sum of the Null values
concatenated_df.select(*[sum(col(c).isNull().cast("int")).alias(c) for c in concatenated_df.columns]).show()
# Out:
# +----+--------+------------+---------+
# |HCHO|Location|Current date|Next date|
# +----+--------+------------+---------+
# |4864|       0|           0|        0|
# +----+--------+------------+---------+

# %%
import matplotlib.pyplot as plt


# Extract the values from the DataFrame column
column_values = pandas_df['HCHO']

# Plot the histogram
plt.hist(column_values, bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of HCHO')

# Show the plot
plt.show()

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import coalesce, col, lag, lead, count

# Initialize a counter for null values
null_count = concatenated_df.filter(col("HCHO").isNull()).count()

# Continue the process until there are no nulls left
while null_count > 0:
    # Define the window specifications
    backward_windowSpec = Window.orderBy("Current Date")
    forward_windowSpec = Window.orderBy("Current Date")
    
    # Use lag to carry the last observation forward
    previous_value = lag("HCHO", 1).over(backward_windowSpec)
    concatenated_df = concatenated_df.withColumn("HCHO", coalesce("HCHO", previous_value))
    
    # Use lead to carry the next observation backward
    next_value = lead("HCHO", 1).over(forward_windowSpec)
    concatenated_df = concatenated_df.withColumn("HCHO", coalesce("HCHO", next_value))
    
    # Update the null count
    null_count = concatenated_df.filter(col("HCHO").isNull()).count()

# concatenated_df now has the nulls filled using a combination of LOCF and NOCB

# %%
# Checking the sum of the Null values
concatenated_df.select(*[sum(col(c).isNull().cast("int")).alias(c) for c in concatenated_df.columns]).show()
# Out:
# +----+--------+------------+---------+
# |HCHO|Location|Current date|Next date|
# +----+--------+------------+---------+
# |   0|       0|           0|        0|
# +----+--------+------------+---------+

# %%
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = concatenated_df.toPandas()

# %%
pandas_df
# Out:
#            HCHO             Location Current date   Next date
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02
# ...         ...                  ...          ...         ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01
#
# [12782 rows x 4 columns]

# %%
pandas_df.duplicated().sum()
# Out:
# 0

# %%
pandas_df.describe()
# Out:
#                HCHO
# count  12782.000000
# mean       0.000119
# std        0.000097
# min       -0.000352
# 25%        0.000058
# 50%        0.000111
# 75%        0.000173
# max        0.000900

# %%
import matplotlib.pyplot as plt


# Extract the values from the DataFrame column
column_values = pandas_df['HCHO']

# Plot the histogram
plt.hist(column_values, bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of HCHO')

# Show the plot
plt.show()

# %%
import seaborn as sns

# Extract the values from the DataFrame column
column_values = pandas_df['HCHO']

# Plot the box plot
sns.boxplot(x=column_values)

# Add labels and title
plt.ylabel('HCHO Values')
plt.title('Box Plot of HCHO')

# Show the plot
plt.show()

# %% [markdown]
# ### Checking violin plot when handling outliers, box plot for not enough for that, not only that we should have to use doamian knowledge

# %%
# Extract the values from the DataFrame column
column_values = pandas_df['HCHO']

# Plot the violin plot
sns.violinplot(x=column_values)

# Add labels and title
plt.ylabel('HCHO Values')
plt.title('Violin Plot of HCHO')

# Show the plot
plt.show()

# %%
q1 = pandas_df['HCHO'].quantile(0.25)
q3 = pandas_df['HCHO'].quantile(0.75)

IQR = q3-q1
lower_bound = q1 - 1.5*IQR
upper_bound = q3 + 1.5*IQR
lower_bound,upper_bound
# Out:
# (-0.0001128555311122474, 0.0003439989012229486)

# %%
df_IQR = pandas_df[(pandas_df['HCHO']>lower_bound) & (pandas_df['HCHO']<upper_bound)]

# %%
# Extract the values from the DataFrame column
column_values = df_IQR['HCHO']

# Plot the box plot
sns.boxplot(x=column_values)

# Add labels and title
plt.ylabel('HCHO Values')
plt.title('Box Plot of HCHO after IQR outlier handling')

# Show the plot
plt.show()

# %%
df_IQR
# Out:
#            HCHO             Location Current date   Next date
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02
# ...         ...                  ...          ...         ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01
#
# [12408 rows x 4 columns]

# %%
plt.hist(pandas_df.HCHO, bins=25, rwidth=0.8)
plt.xlabel('HCHO')
plt.ylabel('Count')
plt.show()

# %%
upper_limit = pandas_df.HCHO.mean()+ 3* pandas_df.HCHO.std()
upper_limit
# Out:
# 0.000408440559323617

# %%
lower_limit = pandas_df.HCHO.mean()- 3* pandas_df.HCHO.std()
lower_limit
# Out:
# -0.0001708394603585672

# %%
df_hist = pandas_df[(pandas_df['HCHO']>lower_limit) & (pandas_df['HCHO']<upper_limit)]

# %%
# Extract the values from the DataFrame column
column_values = df_hist['HCHO']

# Plot the box plot
sns.boxplot(x=column_values)

# Add labels and title
plt.ylabel('HCHO Values')
plt.title('Box Plot of HCHO after 3-Sigma outlier handling')

# Show the plot
plt.show()

# %%
df_hist
# Out:
#            HCHO             Location Current date   Next date
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02
# ...         ...                  ...          ...         ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01
#
# [12654 rows x 4 columns]

# %%
pandas_df['Z-Score'] = (pandas_df.HCHO - pandas_df.HCHO.mean()) / pandas_df.HCHO.std()
pandas_df
# Out:
#            HCHO             Location Current date   Next date   Z-Score
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02  0.809794
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02  0.809794
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02  0.593193
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02  0.593193
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02  0.593193
# ...         ...                  ...          ...         ...       ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01 -0.398122
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01 -0.398122
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01 -0.553018
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01 -0.553018
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01 -0.553018
#
# [12782 rows x 5 columns]

# %%
df_zscore = pandas_df[(pandas_df['Z-Score']>-3) &(pandas_df['Z-Score']<3)]
df_zscore
# Out:
#            HCHO             Location Current date   Next date   Z-Score
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02  0.809794
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02  0.809794
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02  0.593193
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02  0.593193
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02  0.593193
# ...         ...                  ...          ...         ...       ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01 -0.398122
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01 -0.398122
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01 -0.553018
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01 -0.553018
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01 -0.553018
#
# [12654 rows x 5 columns]

# %%
# Extract the values from the DataFrame column
column_values = df_zscore['HCHO']

# Plot the box plot
sns.boxplot(x=column_values)

# Add labels and title
plt.ylabel('HCHO Values')
plt.title('Box Plot of HCHO after Z-SCore outlier handling')

# Show the plot
plt.show()

# %%
pandas_df = df_IQR
pandas_df.isnull().sum()
# Out:
# HCHO            0
# Location        0
# Current date    0
# Next date       0
# dtype: int64

# %%
for column in pandas_df.columns:
    unique_values = pandas_df[column].unique()
    print()
    print(f"Unique values in column '{column}': {unique_values}")
    print()
# Out:
# Unique values in column 'HCHO': [1.96983440e-04 1.76071346e-04 8.82972554e-05 ... 1.16658954e-04
#  8.03631756e-05 6.54085299e-05]
#
#
# Unique values in column 'Location': ['Colombo Proper' 'Deniyaya, Matara' 'Nuwara Eliya Proper' 'Kandy Proper'
#  'Bibile, Monaragala' 'Kurunegala Proper' 'Jaffna Proper']
#
#
# Unique values in column 'Current date': [datetime.date(2019, 1, 1) datetime.date(2019, 1, 2)
#  datetime.date(2019, 1, 3) ... datetime.date(2023, 12, 29)
#  datetime.date(2023, 12, 30) datetime.date(2023, 12, 31)]
#
#
# Unique values in column 'Next date': [datetime.date(2019, 1, 2) datetime.date(2019, 1, 3)
#  datetime.date(2019, 1, 4) ... datetime.date(2023, 12, 30)
#  datetime.date(2023, 12, 31) datetime.date(2024, 1, 1)]

# %%
import pandas as pd

# Sample DataFrame
df = df_hist

# Function to check if data in a column is in the correct format
def check_column_format(column):
    # Check if the column contains numeric values
    if pd.to_numeric(column, errors='coerce').notnull().all():
        return "Numeric"
    # Check if the column contains date values
    elif pd.to_datetime(column, errors='coerce').notnull().all():
        return "Date"
    # If neither numeric nor date, consider it as a string
    else:
        return "String"

# Iterate through each column and check its format
for column in df.columns:
    format_type = check_column_format(df[column])
    print(f"Column '{column}' is of type: {format_type}")
# Out:
# Column 'HCHO' is of type: Numeric
# Column 'Location' is of type: String
# Column 'Current date' is of type: Date
# Column 'Next date' is of type: Date
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24796\1286803899.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   elif pd.to_datetime(column, errors='coerce').notnull().all():

# %%
df_hist
# Out:
#            HCHO             Location Current date   Next date
# 0      0.000197       Colombo Proper   2019-01-01  2019-01-02
# 1      0.000197     Deniyaya, Matara   2019-01-01  2019-01-02
# 2      0.000176  Nuwara Eliya Proper   2019-01-01  2019-01-02
# 3      0.000176         Kandy Proper   2019-01-01  2019-01-02
# 4      0.000176   Bibile, Monaragala   2019-01-01  2019-01-02
# ...         ...                  ...          ...         ...
# 12777  0.000080  Nuwara Eliya Proper   2023-12-31  2024-01-01
# 12778  0.000080         Kandy Proper   2023-12-31  2024-01-01
# 12779  0.000065   Bibile, Monaragala   2023-12-31  2024-01-01
# 12780  0.000065    Kurunegala Proper   2023-12-31  2024-01-01
# 12781  0.000065        Jaffna Proper   2023-12-31  2024-01-01
#
# [12654 rows x 4 columns]

# %% [markdown]
# ### Save concatanated and preprocessed dataset as csv file

# %%
df_hist.to_csv('dataset/hcho.csv', index=False)
